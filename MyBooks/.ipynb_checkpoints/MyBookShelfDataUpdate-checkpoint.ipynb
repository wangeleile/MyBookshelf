# %% [markdown]
# # My Bookshelf
#
# With this tool I would like to generate a database from where I can start to visualize my bookshelf.
#
# Good Example is this: https://github.com/tanykim/best-bookshelf

# %%
import pandas as pd

# Import CSV file
df = pd.read_csv('books.csv')

df.head()
# Out:
#     Book Id                                             Title  \
# 0  32855119  Die Eule von Askir (Das Geheimnis von Askir, #6)
# 1     61907                                        Der Kadett
# 2   2180460                                    Cordelias Ehre
# 3     61905                    Barrayar (Vorkosigan Saga, #7)
# 4   3006201                         Barrayar: Der Botschafter
#
#                  Author             Author l-f Additional Authors  \
# 0      Richard Schwartz      Schwartz, Richard                NaN
# 1  Lois McMaster Bujold  Bujold, Lois McMaster         Edda Petri
# 2  Lois McMaster Bujold  Bujold, Lois McMaster  Michael Morgental
# 3  Lois McMaster Bujold  Bujold, Lois McMaster                NaN
# 4  Lois McMaster Bujold  Bujold, Lois McMaster                NaN
#
#             ISBN            ISBN13  My Rating  Average Rating       Publisher  \
# 0            =""               =""          4            4.43    Piper ebooks
# 1  ="3453149076"  ="9783453149076"          5            4.27           Heyne
# 2  ="3453520017"  ="9783453520011"          3            4.33           Heyne
# 3  ="0743468414"  ="9780743468411"          3            4.29  Gardners Books
# 4  ="3453521277"  ="9783453521278"          3            4.52           Heyne
#
#       ...        Date Read  Date Added  Bookshelves  \
# 0     ...              NaN  2017/05/06          NaN
# 1     ...       1996/05/09  2015/05/09          NaN
# 2     ...       1996/05/09  2015/05/09          NaN
# 3     ...       1996/05/09  2015/05/09          NaN
# 4     ...       1996/05/09  2015/05/09          NaN
#
#    Bookshelves with positions Exclusive Shelf My Review Spoiler Private Notes  \
# 0                         NaN            read       NaN     NaN           NaN
# 1                         NaN            read       NaN     NaN           NaN
# 2                         NaN            read       NaN     NaN           NaN
# 3                         NaN            read       NaN     NaN           NaN
# 4                         NaN            read       NaN     NaN           NaN
#
#   Read Count Owned Copies
# 0          1            0
# 1          1            0
# 2          1            0
# 3          1            0
# 4          1            0
#
# [5 rows x 24 columns]
